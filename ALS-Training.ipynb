# %% [markdown]
# # Imports

# %%
import os; os.environ['OPENBLAS_NUM_THREADS']='1'
import numpy as np
import pandas as pd
import implicit
from scipy.sparse import coo_matrix
from implicit.evaluation import mean_average_precision_at_k
from implicit.evaluation import ndcg_at_k

# %% [markdown]
# # Load dataframes

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/training_set.csv')
df['rating'] = df['Click'] + 5*df['Purchase']
# df = df.groupby('UserId').tail(20)
df = df[['UserId', 'ItemId', 'rating']]

user_list = df['UserId'].unique()
# user_list_denoise = user_list[(user_list<=30)].index.to_list()

# %%
test = pd.read_csv('data/public_testset.csv', names=['user_id'] + [f'item_id_{i}' for i in range(1,1001)])
test_user_id = test['user_id'].values

# %%
user_map = {UserId: index for index, UserId in enumerate(user_list)}
user_map = pd.DataFrame(list(user_map.items()), columns=['UserId', 'index'])
user_map.head()
# Out:
#        UserId  index
# 0  tyviMi4b8Q      0
# 1  PGcvoaV6Gn      1
# 2  vZK9GTxbNA      2
# 3  Sr1MiLP6VX      3
# 4  y9iZADrbdu      4

# %% [markdown]
# ## Assign autoincrementing ids starting from 0 to both users and items

# %%
ALL_USERS = df['UserId'].unique().tolist()
ALL_ITEMS = df['ItemId'].unique().tolist()

user_ids = dict(list(enumerate(ALL_USERS)))
item_ids = dict(list(enumerate(ALL_ITEMS)))

user_map = {u: uidx for uidx, u in user_ids.items()}
item_map = {i: iidx for iidx, i in item_ids.items()}

df['UserId'] = df['UserId'].map(user_map)
df['ItemId'] = df['ItemId'].map(item_map)

# %%
test['user_index'] = test['user_id'].map(user_map)
test_user_index = test['user_index'].values

# %%
# Split data into train and test sets (90% for train, 10% for test)
train_df = df.sample(frac=0.95, random_state=42)  # 90% for train
test_df = df.drop(train_df.index)  # Remaining 10% for test

# %% [markdown]
# ## Create coo_matrix (user x item) and csr matrix (user x item)
#
# It is common to use scipy sparse matrices in recommender systems, because the main core of the problem is typically modeled as a matrix with users and items, with the values representing whether the user purchased (or liked) an items. Since each user purchases only a small fraction of the catalog of products, this matrix is full of zero (aka: it's sparse).
#
# In a very recent release they did an API breaking change, so be aware of that: https://github.com/benfred/implicit/releases
# In this notebook we are using the latest version, so everything is aligned with (user x item)
#
# **We are using (user x item) matrices, both for training and for evaluating/recommender.**
#
# In the previous versions the training procedure required a COO item x user
#
# For evaluation and prediction, on the other hand, CSR matrices with users x items format should be provided.
#
#
# ### About COO matrices
# COO matrices are a kind of sparse matrix.
# They store their values as tuples of `(row, column, value)` (the coordinates)
#
# You can read more about them here:
# * https://en.wikipedia.org/wiki/Sparse_matrix#Coordinate_list_(COO)
# * https://scipy-lectures.org/advanced/scipy_sparse/coo_matrix.html
#
# From https://het.as.utexas.edu/HET/Software/Scipy/generated/scipy.sparse.coo_matrix.html
#
# ```python
# >>> row  = np.array([0,3,1,0]) # user_ids
# >>> col  = np.array([0,3,1,2]) # item_ids
# >>> data = np.array([4,5,7,9]) # a bunch of ones of lenght unique(user) x unique(items)
# >>> coo_matrix((data,(row,col)), shape=(4,4)).todense()
# matrix([[4, 0, 9, 0],
#         [0, 7, 0, 0],
#         [0, 0, 0, 0],
#         [0, 0, 0, 5]])
# ```
#
# ## About CSR matrices
# * https://en.wikipedia.org/wiki/Sparse_matrix#Compressed_sparse_row_(CSR,_CRS_or_Yale_format)

# %%
row = df['UserId'].values
col = df['ItemId'].values
# data = np.ones(train_df.shape[0])
data = df['rating'].values
coo_train = coo_matrix((data, (row, col)), shape=(len(ALL_USERS), len(ALL_ITEMS)))
coo_train
# Out:
# <COOrdinate sparse matrix of dtype 'int64'
# 	with 389923 stored elements and shape (36751, 83102)>

# %% [markdown]
# # Validation

# %% [markdown]
# ## Functions required for validation

# %%
def to_user_item_coo(df):
    """ Turn a dataframe with transactions into a COO sparse items x users matrix"""
    row = df['UserId'].values
    col = df['ItemId'].values
    # data = np.ones(df.shape[0])
    data = df['rating'].values
    coo = coo_matrix((data, (row, col)), shape=(len(ALL_USERS), len(ALL_ITEMS)))
    return coo


def split_data(df, validation_days=7):
    """ Split a pandas dataframe into training and validation data, using <<validation_days>>
    """
    validation_cut = df['t_dat'].max() - pd.Timedelta(validation_days)

    df_train = df[df['t_dat'] < validation_cut]
    df_val = df[df['t_dat'] >= validation_cut]
    return df_train, df_val

def get_val_matrices(df, validation_days=7):
    """ Split into training and validation and create various matrices
        
        Returns a dictionary with the following keys:
            coo_train: training data in COO sparse format and as (users x items)
            csr_train: training data in CSR sparse format and as (users x items)
            csr_val:  validation data in CSR sparse format and as (users x items)
    
    """
    df_train, df_val = train_df, test_df
    coo_train = to_user_item_coo(df_train)
    coo_val = to_user_item_coo(df_val)

    csr_train = coo_train.tocsr()
    csr_val = coo_val.tocsr()
    
    return {'coo_train': coo_train,
            'csr_train': csr_train,
            'csr_val': csr_val
          }


def validate(model, matrices, factors=200, iterations=20, regularization=0.01, show_progress=True):
    """ Train an ALS model with <<factors>> (embeddings dimension) 
    for <<iterations>> over matrices and validate with MAP@12
    """
    coo_train, csr_train, csr_val = matrices['coo_train'], matrices['csr_train'], matrices['csr_val']
    
    # model = implicit.als.AlternatingLeastSquares(factors=factors, 
    #                                              iterations=iterations, 
    #                                              regularization=regularization, 
    #                                              random_state=42)
    # model.fit(coo_train, show_progress=show_progress)
    
    # The MAPK by implicit doesn't allow to calculate allowing repeated items, which is the case.
    # TODO: change MAP@12 to a library that allows repeated items in prediction
    # map12 = mean_average_precision_at_k(model, csr_train, csr_val, K=12, show_progress=show_progress, num_threads=4)
    ndcg = ndcg_at_k(model, csr_train, csr_val, K=10, show_progress=show_progress, num_threads=4)
    print(f"Factors: {factors:>3} - Iterations: {iterations:>2} - Regularization: {regularization:4.3f} ==> NDCG@10: {ndcg:6.5f}")
    return ndcg

# %%
matrices = get_val_matrices(df)

# %%
# %%time
# best_map12 = 0
# for factors in [40, 50, 60, 100, 200, 500, 1000]:
#     for regularization in [0.01]:
#         map12 = validate(matrices, factors, iterations, regularization, show_progress=False)
#         if map12 > best_map12:
#             best_map12 = map12
#             best_params = {'factors': factors, 'iterations': iterations, 'regularization': regularization}
#             print(f"Best MAP@12 found. Updating: {best_params}")

factors = 1000
iterations = 200
regularization = 0.01
best_params = {'factors': factors, 'iterations': iterations, 'regularization': regularization}

# %% [markdown]
# # Training over the full dataset

# %%
coo_train = to_user_item_coo(df)
csr_train = coo_train.tocsr()

# %%
def train(coo_train, factors=200, iterations=15, regularization=0.01, show_progress=True):
    model = implicit.als.AlternatingLeastSquares(factors=factors, 
                                                 iterations=iterations, 
                                                 regularization=regularization, 
                                                 random_state=42)
    model.fit(coo_train, show_progress=show_progress)
    return model

# %%
model = train(coo_train, **best_params)
# Out:
# /opt/conda/envs/rapids-24.10/lib/python3.11/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.01801466941833496 seconds
#   warnings.warn(
#   0%|          | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model = train(coo_train, **best_params)
#
# Cell In[13], line 6, in train(coo_train, factors, iterations, regularization, show_progress)
#       1 def train(coo_train, factors=200, iterations=15, regularization=0.01, show_progress=True):
#       2     model = implicit.als.AlternatingLeastSquares(factors=factors,
#       3                                                  iterations=iterations,
#       4                                                  regularization=regularization,
#       5                                                  random_state=42)
# ----> 6     model.fit(coo_train, show_progress=show_progress)
#       7     return model
#
# File /opt/conda/envs/rapids-24.10/lib/python3.11/site-packages/implicit/cpu/als.py:163, in AlternatingLeastSquares.fit(self, user_items, show_progress, callback)
#     161 for iteration in range(self.iterations):
#     162     s = time.time()
# --> 163     solver(
#     164         Cui,
#     165         self.user_factors,
#     166         self.item_factors,
#     167         self.regularization,
#     168         num_threads=self.num_threads,
#     169     )
#     170     solver(
#     171         Ciu,
#     172         self.item_factors,
#    (...)
#     175         num_threads=self.num_threads,
#     176     )
#     177     progress.update(1)
#
# File _als.pyx:148, in implicit.cpu._als.least_squares_cg()
#
# File _als.pyx:164, in implicit.cpu._als._least_squares_cg()
#
# File /opt/conda/envs/rapids-24.10/lib/python3.11/site-packages/numpy/lib/_twodim_base_impl.py:159, in eye(N, M, k, dtype, order, device, like)
#     155         raise ValueError("Input must be >= 1-d.")
#     156     return m[::-1, ...]
# --> 159 @set_array_function_like_doc
#     160 @set_module('numpy')
#     161 def eye(N, M=None, k=0, dtype=float, order='C', *, device=None, like=None):
#     162     """
#     163     Return a 2-D array with ones on the diagonal and zeros elsewhere.
#     164
#    (...)
#     211
#     212     """
#     213     if like is not None:
#
# KeyboardInterrupt:

# %%
save_path = "runs/ALS"
os.makedirs(save_path, exist_ok=True)

# %%
import pickle
with open(f"{save_path}/user_embedding.pkl", "wb") as f:
    pickle.dump(model.user_factors, f)
    
with open(f"{save_path}/item_embedding.pkl", "wb") as f:
    pickle.dump(model.user_factors, f)
    
with open(f"{save_path}/model.pkl", "wb") as f:
    pickle.dump(model, f)

with open(f"{save_path}/usermap.pkl", "wb") as f:
    pickle.dump(user_map, f)

with open(f"{save_path}/itemmap.pkl", "wb") as f:
    pickle.dump(item_map, f)

with open(f"{save_path}/csr_train.pkl", "wb") as f:
    pickle.dump(csr_train, f)

# %%
user_ids
# Out:
# {0: 'tyviMi4b8Q',
#  1: 'PGcvoaV6Gn',
#  2: 'vZK9GTxbNA',
#  3: 'Sr1MiLP6VX',
#  4: 'y9iZADrbdu',
#  5: 'URQmc5J6kH',
#  6: '1j704xkcse',
#  7: 'X2oDWpC701',
#  8: '4KWQyiec7N',
#  9: 'acDdQa67Fk',
#  10: '6uuqsSXcN7',
#  11: 'dCc4KKz7UU',
#  12: '9UJHmCRccr',
#  13: 'gn1UE5t7kE',
#  14: 'C5ihgxLcrb',
#  15: 'iNPv8pm7zx',
#  16: 'Ff78ahEd7K',
#  17: 'lxoL2Zg8Fh',
#  18: 'IGVYUR8dM4',
#  19: 'oYDmwKZ8UR',
#  20: 'KquzOC1dco',
#  21: 'r8bCq4T8jB',
#  22: 'NQJPIwvdrX',
#  23: 'uj0ckoN8zu',
#  24: 'Q1hqChod6H',
#  25: 'wJP3eZG9Ee',
#  26: 'Tb6G6RieM1',
#  27: 'ztnTYJA9TO',
#  28: 'VCVh0Bcebl',
#  29: '2UCuS339j7',
#  30: 'Ymt7uwVeqU',
#  31: '54bKMox9yr',
#  32: 'bMIYogPe6E',
#  33: '7fzlGYq9Db',
#  34: 'exhyiQIeLy',
#  35: 'AFOBAJkATL',
#  36: 'hX5PcBCfai',
#  37: 'Dpnc43eAi4',
#  38: 'j7UpWv5fqR',
#  39: 'GQB2ynXAxo',
#  40: 'mitFQfzf5B',
#  41: 'J0aTsYRADY',
#  42: 'pIHgKQsfKv',
#  43: 'LaztmIKASI',
#  44: 'stg6EAmgae',
#  45: 'OBNKg2EBh1',
#  46: 'uT5X8vggpO',
#  47: 'Rlmkan7Bxl',
#  48: 'x3Tx2fZg48',
#  49: 'UMBBUX1BCV',
#  50: '0esOwPTgKs',
#  51: 'WwZbOHuBRE',
#  52: '3EHoqAMgZb',
#  53: 'ZWy1I2oBhy',
#  54: '6pfFkuGhoL',
#  55: 'c7NSCmiCwi',
#  56: '8P4fee9h45',
#  57: 'fhls6XbCBS',
#  58: 'BzT6YP3hJo',
#  59: 'iHAJ0HVCRB',
#  60: 'EarWS9whYY',
#  61: 'ksZju1OCgv',
#  62: 'HAGxMtqhoI',
#  63: 'nSxAomICvf',
#  64: 'KkfNGeki32',
#  65: 'q3MaiWBDBP',
#  66: 'ML3oAOdiIl',
#  67: 'tdl1cG5DQ8',
#  68: 'PvSE49XiYV',
#  69: 'vD9RW1yDfs',
#  70: 'SWreytQinF',
#  71: 'yoYsQlsDvc',
#  72: 'V6F5sdKi2z',
#  73: '1OxIKVmEAL',
#  74: 'XgeVmODjIi',
#  75: '4zLjEGfEP5',
#  76: 'aH3wg87jXS',
#  77: '7Zk980ZEfp',
#  78: 'drRMas0jmC',
#  79: '999a2lSEuZ',
#  80: 'gSqnUduj2v',
#  81: 'CkX0wVME9I',
#  82: 'j2FDONojHf',
#  83: 'FKwQqFFFP2',
#  84: 'lcdeI7hkWP',
#  85: 'IuLrk09Fem',
#  86: 'oD24Csbkm9',
#  87: 'KVjHek2FtW',
#  88: 'rnRV6cUk1s',
#  89: 'N58iYUwF9F',
#  90: 'uNpv0NOkGc',
#  91: 'QgX8SFqFOz',
#  92: 'wyEMu7HlWM',
#  93: 'TGvZMzjGdj',
#  94: 'zYdmorBll6',
#  95: 'WqKzGjdGtS',
#  96: '291Dic5l0p',
#  97: 'YRjQAUWG8C',
#  98: '5jQdcMylGZ',
#  99: 'b18q3EQGNw',
#  100: '8Jp3V6slVJ',
#  101: 'ecWHxyJGdg',
#  102: 'AuEUPrlmk2',
#  103: 'hCvhrjDHsP',
#  104: 'DUcuJbfm0m',
#  105: 'kmK8lT7H89',
#  106: 'G51LDLYmFW',
#  107: 'mNiYfE0HNt',
#  108: 'JfQl76SmVG',
#  109: 'px7zZyuHcc',
#  110: 'LFoC1qLmkz',
#  111: 'sXWPTinIsM',
#  112: 'OqDcvaFnzj',
#  113: 'v8upNThI76',
#  114: 'RQc3pL9nFT',
#  115: 'xiJGHDaIMq',
#  116: 'U00Tj52nUD',
#  117: '0JigBxUIcZ',
#  118: 'XbPudqwnjw',
#  119: '3t675iNIrJ',
#  120: 'ZBoKXapnzg',
#  121: '6TVXzSHJ63',
#  122: 'cmClRKjoEQ',
#  123: '94uytCBJMn',
#  124: 'fMbBL5coT9',
#  125: 'BeIOnx4JbW',
#  126: 'iw0cFpWojt',
#  127: 'EFhphhyJqG',
#  128: 'kXO29ZPoyd',
#  129: 'Hp6FbSrJ60',
#  130: 'n7nS3KJoDN',
#  131: 'KPUgVClKLj',
#  132: 'qiCtx4DpT6',
#  133: 'M0t6PweKaT',
#  134: 'tIaJro6piq',
#  135: 'PaIXJhYKqD',
#  136: 'wszklZ0pxa',
#  137: 'SAgxDRRK5x',
#  138: 'yTOAfJtpDK',
#  139: 'Vl5O7BLKKg',
#  140: '13mbZ4nqS3',
#  141: 'YLUo1wFLaQ',
#  142: '4dB1Togqhn',
#  143: 'awsEvg8LpA',
#  144: '7EaSNYaqxX',
#  145: 'dWHfpQ2L4u',
#  146: 'AoysHJTqCG',
#  147: 'g6g5jBvLKd',
#  148: 'CPNJB3NqR0',
#  149: 'jh4WdvpLZN',
#  150: 'Fzmj5nHrhk',
#  151: 'lHTwXgiMo7',
#  152: 'IZAAzYArwU',
#  153: 'ossNRQcM4q',
#  154: 'LAZatI4rBD',
#  155: 'rSGnLAVMJa',
#  156: 'Nky1n2xrRx',
#  157: 'u2fEFvPMYK',
#  158: 'QLMRhnrrgh',
#  159: 'xd4e9fJNo4',
#  160: 'TvlrbXksvQ',
#  161: 'zDS53PCN3n',
#  162: 'WVAIVIesBA',
#  163: '2nrVxA6NIX',
#  164: 'Z6YiP2YsQu',
#  165: '5OGwruzNYH',
#  166: 'bgx9JmRsfe',
#  167: '8yeMletNn1',
#  168: 'eGMZDXLsvN',
#  169: 'AZ3nfPmO2k',
#  170: 'hrk07HEtA7',
#  171: 'D9SDZ9gOIU',
#  172: 'kR9Q118tPr',
#  173: 'GjqdTuaOXE',
#  174: 'm2Yrvm1tfb',
#  175: 'JKF4NeTOmx',
#  176: 'pcwHpWvtuK',
#  177: 'MueUHONO2h',
#  178: 'sCLijGou94',
#  179: 'OV2vB9GPHR',
#  180: 'vnk8d1iuPo',
#  181: 'R5RL5tAPWB',
#  182: 'yN8ZXlcueX',
#  183: 'Ufqmzd3Pmu',
#  184: '0xXzRWVutH',
#  185: 'XGFCtOxP1e',
#  186: '3YwQLGPu91',
#  187: 'aqddn8qPGO',
#  188: '68LqF0IvOl',
#  189: 'cQ23hskQW7',
#  190: '9jjG9lCvdU',
#  191: 'f1RUbdeQlr',
#  192: 'BJ8h3V5vtE',
#  193: 'ibpuVNXQ1b',
#  194: 'EtX7xFzv8y',
#  195: 'lCELP8RQGL',
#  196: 'HUvYr0svOi',
#  197: 'nmdlJsKQV4',
#  198: 'K4KylkmwdR',
#  199: 'qM1CDcERlo',
#  200: 'NfjPfUgwsB',
#  201: 'txQc7N7R0Y',
#  202: 'PF7pZFZw8v',
#  203: 'wXp2171RFI',
#  204: 'SpWGTzTwNe',
#  205: 'z8DTvruRV1',
#  206: 'VQvgNkMwcO',
#  207: '1ictpcoSkl',
#  208: 'Y0J7HUGxs8',
#  209: '4I1KjMiSzV',
#  210: 'baiXBE9x7s',
#  211: '7tPkd6bSFE',
#  212: 'dB7y5z3xMb',
#  213: 'AToBXrVSUy',
#  214: 'glVOzjwxcL',
#  215: 'C3DbRbOSji',
#  216: 'jMuptTqxr5',
#  217: 'Feb2LMITzS',
#  218: 'mwJFnEky6p',
#  219: 'IE0SF6BTEB',
#  220: 'oWhfhydyMY',
#  221: 'LpPt9q5TTv',
#  222: 'r766biXybI',
#  223: 'OPnJ3bzTjf',
#  224: 'uhVWVTQyq2',
#  225: 'QzCkxLsTyP',
#  226: 'xItxODKz6l',
#  227: 'TabAq5mUD8',
#  228: '0sINIyDzLV',
#  229: 'WAzbkqfUTs',
#  230: '2ShoCi7zaF',
#  231: 'ZlO1eaZUic',
#  232: '535E6S1zqz',
#  233: 'bLnSYKSUxL',
#  234: '8dUf0Duz5i',
#  235: 'evBsS5MUD5',
#  236: 'BDt5uxo0KS',
#  237: 'hWaIMpFVSp',
#  238: 'DoHWohh0aC',
#  239: 'k6zjGa9VhZ',
#  240: 'GOgwiSb0pv',
#  241: 'ngN9AK3VxI',
#  242: 'Jz5NcCU04f',
#  243: 'pHma44wVC2',
#  244: 'MZTnWwO0KP',
#  245: 'srB0ypqWRm',
#  246: 'P9sEQhH1Z9',
#  247: 'vSZRsZjWhW',
#  248: 'RkHeKRB1os',
#  249: 'y2yrmJdWwF',
#  250: 'UKf4EC514c',
#  251: '1cNIg4WWBz',
#  252: 'Xv4V8wy1JM',
#  253: '3DliaoQWRj',
#  254: 'aVTv2gs1Y6',
#  255: '6nA9UYJXgS',
#  256: 'c5rMwRl2op',
#  257: '9OZZOJDXvC',
#  258: 'fgGmqBf23Z',
#  259: 'Cyx0I37XBw',
#  260: 'iGfDkvY2IJ',
#  261: 'EYMQCo0XQg',
#  262: 'lq3degS2Y2',
#  263: 'H9lr6YuXfP',
#  264: 'oRS4YQL2nm',
#  265: 'Kj9H0InYv9',
#  266: 'q1rUSAF32W',
#  267: 'NJYhu3hYAt',
#  268: 'tcGvMv93IG',
#  269: 'Qux8onaYPd',
#  270: 'wCeLGf23Xz',
#  271: 'SUMYiXUYfM',
#  272: 'zm3mAQw3mj',
#  273: 'V5kzcINYu6',
#  274: '1NSC4Ap42T',
#  275: 'Yf9PW2HZ9q',
#  276: '4xqdyuj4HD',
#  277: 'bFYqQmBZPZ',
#  278: '7YF3sfc4Ww',
#  279: 'dqwGKX4ZeJ',
#  280: 'A8eTmPW4mg',
#  281: 'gQLhEHyZu3',
#  282: 'Di2ug9P41Q',
#  283: 'j0k782rZ9n',
#  284: 'FJRKauJ5H9',
#  285: 'mb8Y2mlaOW',
#  286: 'ItqlUeD5Wt',
#  287: 'pBXywWeaeG',
#  288: 'LTEBOO65ld',
#  289: 'rmwPqHYat0',
#  290: 'O4dcI9051N',
#  291: 'uMKpk1Sa8j',
#  292: 'Re22Ctt5G6',
#  293: 'xwjGelLbOT',
#  294: 'TFQT6en6Vq',
#  295: '0X8gYWFbdD',
#  296: 'Wppt0Og6la',
#  297: '27W6SG8bsx',
#  298: 'ZPEKu8a60K',
#  299: '5ivXM02b8g',
#  300: 'c0ckotU6F3',
#  301: '8IKxGlvbNQ',
#  302: 'ea1BidN6Vn',
#  303: 'BsiOAVpccA',
#  304: 'hBQbcNH7kX',
#  305: 'ET7o4Gicsu',
#  306: 'klo2W8A7zG',
#  307: 'G3WFy0cc7d',
#  308: 'nLDSQs47F0',
#  309: 'JdufskWcMN',
#  310: 'qwcsKcx7Uk',
#  311: 'MEJ6mVPcc7',
#  312: 'sW0JENr7jU',
#  313: 'PoiWgFJdrq',
#  314: 'v6Pj87k8zD',
#  315: 'RP6xazCd6a',
#  316: 'yhoA2se8Ex',
#  317: 'UzVNUk6dMK',
#  318: '1HCawcY8Th',
#  319: 'XZuoOUzdb4',
#  320: '3sb1qMR8jQ',
#  321: 'aAIEIEtdqn',
#  322: '6S0Rk7L9yA',
#  323: 'dkhfCzme6X',
#  324: '92OserE9Du',
#  325: 'fL656jgeLH',
#  326: 'CdnIYb89Te',
#  327: 'ivUV0Uaea1',
#  328: 'FDCjSM19iN',
#  329: 'lVtwuETeqk',
#  330: 'Hoa9M6v9x7',
#  331: 'o6IMoyNe5U',
#  332: 'KOzaGqoADr',
#  333: 'rggnijGfKE',
#  334: 'NyO0AbiASb',
#  335: 'tG5DcTAfax',
#  336: 'QZmR4LcAhK',
#  337: 'wrUeWD3fph',
#  338: 'S9Bry6VAx4',
#  339: 'zRs4Qyxf4R',
#  340: 'VjaHsqPACo',
#  341: '22HVKiqgKB',
#  342: 'YKyimaIBRX',
#  343: '4cgvESkgZu',
#  344: 'buN8gLCBhH',
#  345: '7C4M8Degoe',
#  346: 'eVmZa55Bw1',
#  347: 'AnTm2xXg4O',
#  348: 'g5AzUpzBBl',
#  349: 'DNsDwiRgJ8',
#  350: 'jfZQOatBRU',
#  351: 'GyGdqSKhYr',
#  352: 'mGyqHKmCgE',
#  353: 'IYf4jCEhob',
#  354: 'pqNHB4gCvy',
#  355: 'L84Udx7h3L',
#  356: 'rRlh5pZCBi',
#  357: 'OjTuXh1hI4',
#  358: 'u1A8zZTCQR',
#  359: 'RJrLRRvhYo',
#  360: 'xbZYtKMDfB',
#  361: 'TtGlLCoinY',
#  362: '0Cxzn4GDvv',
#  363: 'WUfCFwii2I',
#  364: '3mMPho9DAe',
#  365: 'Z43c9gbiI1',
#  366: '5MlqbZ3DPO',
#  367: 'cfS33RViXl',
#  368: '8x9GVJxDf8',
#  369: 'fFrTxBOimV',
#  370: 'BXYgP3qEus',
#  371: 'hpFurwIj2E',
#  372: 'E8x7JokEAb',
#  373: 'kQeKlgBjHy',
#  374: 'HiLXDYdEPL',
#  375: 'n03lfQ5jXi',
#  376: 'JIky7IXEe5',
#  377: 'qbRBZBzjmS',
#  378: 'Mt9O13QEup',
#  379: 'sBqcTvsj1B',
#  380: 'PTXpvnKF9Y',
#  381: 'vlF2NfmkHv',
#  382: 'S4wFpYDFOI',
#  383: 'yMdTHQfkWf',
#  384: 'UeLgjI7Fe2',
#  385: '1w2tBAZklP',
#  386: 'XEj6d21Ftl',
#  387: '4WRJ5uSk18',
#  388: 'ap8XXnuF8V',
#  389: '67pkzfMlGs',
#  390: 'dPXxRXoGOF',
#  391: '9hEAtPFlVc',
#  392: 'gzvOLHhGdz',
#  393: 'CIdbnA9llL',
#  394: 'iaKoF2bGsi',
#  395: 'Fs11hu3l05',
#  396: 'lAjF9mUG8S',
#  397: 'ISQSbewlFp',
#  398: 'ol7f3WOGNC',
#  399: 'K3psVPqmVZ',
#  400: 'rLW5xHHHcv',
#  401: 'NdDJP9jmkI',
#  402: 'tvvWr1BHsf',
#  403: 'QEcjJtdmz2',
#  404: 'wWJwlm5H7P',
#  405: 'To1ADeWmFm',
#  406: 'z6iNfWyHM9',
#  407: 'VOPa7OQmUW',
#  408: '2g7nZGsIcs',
#  409: 'Yzo118JnjF',
#  410: '5HVET1lIrc',
#  411: 'bZDRvtDnzz',
#  412: '7rueNlfI6M',
#  413: 'e9bspd7nEj',
#  414: 'ASJ5HVYIM6',
#  415: 'hk0IjO0nTS',
#  416: 'D2hVBGSIbp',
#  417: 'jKPid8unjC',
#  418: 'Gc6w50MJqZ',
#  419: 'mvn9Xsnoyw',
#  420: 'IDVMzkFJ6J',
#  421: 'pVCZRdhoDg',
#  422: 'LntntV9JL2',
#  423: 's5b0LNaoTP',
#  424: 'OOIDnF2Jam',
#  425: 'ugzQF7Uoi9',
#  426: 'Ryheh0wJqW',
#  427: 'xGOr9sOpxt',
#  428: 'UY54bkpK5G',
#  429: '0rnH3cHpDd',
#  430: 'W9UUVUjKKz',
#  431: '3RBixMBpSM',
#  432: 'ZjtvPFcKaj',
#  433: '61a8r74ph6',
#  434: 'cJHLJzWKpT',
#  435: '8czZlrypxq',
#  436: 'fugmDjQK4D',
#  437: 'BCNzfcrqCZ',
#  438: 'iU5C7UJLKw',
#  439: 'EmmQZMlqRJ',
#  440: 'k5Ud1EDLZg',
#  441: 'HNBqT6eqh3',
#  442: 'nfs3vy6LoQ',
#  443: 'JxaHNrYqwn',
#  444: 'qFHUpj0L49',
#  445: 'MYyhHbSqBW',
#  446: 'tqgujTtLJt',
#  447: 'P8N7BLLrRG',
#  448: 'vQ4LdEnMYd',
#  449: 'SimY56Frg0',
#  450: 'y1TlXygMoN',
#  451: 'VJAyzq8rvj',
#  452: '1bsCRiaM36',
#  453: 'XtZPta2rBT',
#  454: '4BGcLTUMIq',
#  455: 'aUypnLvrQD',
#  456: '7mf3FDNNYa',
#  457: 'd4MGh5psfx',
#  458: '9M4T9xHNnK',
#  459: 'gelgbqisvg',
#  460: 'CwSt3iAN33',
#  461: 'iFA7VacsAQ',
#  462: 'FXrKxS4NIn',
#  463: 'lpYXPKWsQA',
#  464: 'I7GkrCxNXX',
#  465: 'oPxyJ5Psfu',
#  466: 'KieBlxrOnG',
#  467: 'r0MODpJtud',
#  468: 'NI3bfhkO20',
#  469: 'uakp7ZCtAN',
#  470: 'QsS2ZSeOHk',
#  471: 'wB9F1K6tP7',
#  472: 'TTqSTCYOXU',
#  473: 'zlYgv4zteq',
#  474: 'W3FtNwROmD',
#  475: '2Lw6potuua',
#  476: 'YeeJHhLP1x',
#  477: '5wLWjZnu9K',
#  478: 'bE2kBREPHh',
#  479: '8WkxcJguO4',
#  480: 'eoRA4B8PWR',
#  481: 'A78NW4auen',
#  482: 'hPqbyw1PlA',
#  483: 'DhXoQoTutX',
#  484: 'jzE1sgvP1u',
#  485: 'GHwEKYNv8H',
#  486: 'mZdSmQpQGe',
#  487: 'JsKfEJGvO1',
#  488: 'pA2sgBiQVN',
#  489: 'LSj583Avdk',
#  490: 'skQJavcQl7',
#  491: 'O28W2n3vsU',
#  492: 'vLpjUgVQ0r',
#  493: 'RdWwwYxv8E',
#  494: 'xvE9OQPRFb',
#  495: 'UDvNqIrwNx',
#  496: '0VcaIAIRVK',
#  497: 'XoKnk2kwch',
#  498: '3610CvCRk4',
#  499: 'ZOiEenewsR',
#  500: '6gQR6f5Rzo',
#  501: 'cy7eYXXw7B',
#  502: '8Hor0PzRFX',
#  503: 'fZW5SIRwMu',
#  504: 'BrDIuAtSUH',
#  505: 'i9uVM2Kxce',
#  506: 'ERcioumSj1',
#  507: 'kjJvGmExrO',
#  508: 'H209iegSzl',
#  509: 'nKiMAX7x68',
#  510: 'KcPZcPZSEU',
#  511: 'qu6m4H1xMr',
#  512: 'MCo0W9TSTE',
#  513: 'tVVDy1vxbb',
#  514: 'PnCQQuMTjy',
#  515: 'w5udsmoyqL',
#  516: 'SNbrKeGTyi',
#  517: 'yfI4mWiy64',
#  518: 'Vy0HEO9TDR',
#  519: '1GhUgGbyLo',
#  520: 'YYOi893TTB',
#  521: '4q6va1VyaY',
#  522: 'a8n82txTiv',
#  523: '7RVLUlOzqI',
#  524: 'djCYwdqUxe',
#  525: '91tmOWIz51',
#  526: 'gJbzqOkUDO',
#  527: 'CbICIGBzKl',
#  528: 'juzPk8dUS8',
#  529: 'FChdC05zaV',
#  530: 'lUOqesXUhs',
#  531: 'Im536lzzpE',
#  532: 'o4nGYdQUxb',
#  533: 'LMUU0Vs04y',
#  534: 'rfBhSNKVCL',
#  535: 'NxtuuFm0Ki',
#  536: 'uFa7M8DVR5',
#  537: 'QXHKo0f0ZS',
#  538: 'xpzYGs7Vhp',
#  539: 'T8glikZ0oB',
#  540: 'zQNyAc1VwY',
#  541: 'Wi5BcUS04v',
#  542: '20mP4NuWBI',
#  543: 'YITcWFM1Jf',
#  544: '5bBpy7oWR2',
#  545: 'bts2QzG1YP',
#  546: '8BZGsrhWgl',
#  547: 'eTHTKk91o8',
#  548: 'AlygmcbWwV',
#  549: 'h4ftEU313s',
#  550: 'DMN7gMUWBF',
#  551: 'ke4K8Ew1Jc',
#  552: 'GwlXa6OXQz',
#  553: 'mETk2zq2YL',
#  554: 'JXAxUrIXgi',
#  555: 'pprBwjj2n5',
#  556: 'M7ZOObBXvS',
#  557: 'sPGbqTd23p',
#  558: 'OhxoIM5XAC',
#  559: 'vzf2kEW2IZ',
#  560: 'RIMFC6yXQw',
#  561: 'ya3SeyQ3XI',
#  562: 'Uslf6qsYff',
#  563: '0AStYiK3n2',
#  564: 'XS960blYuP',
#  565: '3lrJSTD32m',
#  566: 'Z3YWuLfYA9',
#  567: '6LFjMD73HW',
#  568: 'cdxxo5YYPs',
#  569: '9veAGy03XF',
#  570: 'fELNiqSYec',
#  571: 'BW3aAiu4mz',
#  572: 'iokocaMZuM',
#  573: 'E6R14Sn41j',
#  574: 'lO9EWKFZ96',
#  575: 'HhqRyDh4HS',
#  576: 'nzXfQ59ZOp',
#  577: 'KHFssxa4WC',
#  578: 'qZw5Kp2ZeZ',
#  579: 'NrdImhU4lw',
#  580: 'tALWEawZtJ',
#  581: 'PS2jgSO51g',
#  582: 'wkjw8Kpa82',
#  583: 'S2R9aCH5GP',
#  584: 'zK8M24jaOm',
#  585: 'VcpaUwB5V9',
#  586: '1vXnwpcadW',
#  587: 'YDE0Oh45lt',
#  588: '4VvDqZWasG',
#  589: 'andRIRy50d',
#  590: '75KekJQb8z',
#  591: 'dO1rCCr6FM',
#  592: 'Agj4e4JbNj',
#  593: 'gyQI6wl6V6',
#  594: 'CG7VYoDbcT',
#  595: 'jYpi0ge6kq',
#  596: 'FrWvSY6bsD',
#  597: 'm9D8uRY6zZ',
#  598: 'IRvMMJ0b7w',
#  599: 'ojcZoBS6FJ',
#  600: 'L1JmG3tcMg',
#  601: 'rK1zivL7U3',
#  602: 'OciDAonccQ',
#  603: 'uuPQcgF7jn',
#  604: 'QC7d4Yhcr9',
#  605: 'xUoqWQ87zW',
#  606: 'TmV4xIac6t',
#  607: 'z5DHPA27EG',
#  608: 'WNuUr3UcMd',
#  609: '2fchJvv8T0',
#  610: 'ZxJvlnNdbN',
#  611: '5F08Dfp8jj',
#  612: 'bYiLfXHdq6',
#  613: '8qPY7Qj8yT',
#  614: 'e86lZIAd6q',
#  615: 'BQoz1Ac8DD',
#  616: 'hiVCT24dLa',
#  617: 'D1CPvuW8Tx',
#  618: 'kJucNmxdaK',
#  619: 'GbbqpfP9ig',
#  620: 'ntI3HXreq3',
#  621: 'JB0GjPJ9xQ',
#  622: 'pUhTBHle5n',
#  623: 'MmOhd9C9DA',
#  624: 's46u52eeKX',
#  625: 'PMn7Xu69Su',
#  626: 'veUKzmYeaG',
#  627: 'RxCXRez9hd',
#  628: 'yFtltWRep0',
#  629: 'UXayLOtAxN',
#  630: '0pIBnHLf4k',
#  631: 'X7zOF9nAC7',
#  632: '3Pgch1EfKU',
#  633: 'aiOp9tgARq',
#  634: '6052bl8fZD',
#  635: 'cImF3eaAha',
#  636: '9aUTVW1fpx',
#  637: 'fsBgxOTAwK',
#  638: 'CBstPGvg4h',
#  639: 'iTa6r8NBC4',
#  640: 'ElHKJ0pgJR',
#  641: 'l3yXltGBRn',
#  642: 'HLgkDligZA',
#  643: 'oeNxfdABgX',
#  644: 'Kw4A7Vcgou',
#  645: 'qEmOZN3BwH',
#  646: 'NWTb1GVg3e',
#  647: 'toAoT8xBB1',
#  648: 'P7s1v0PhJN',
#  649: 'wPZFNsrCQk',
#  650: 'ShGSpkIhY7',
#  651: 'zzyfHckCgU',
#  652: 'VHfsjVChnr',
#  653: '1aM6BNeCvE',
#  654: 'Ys4JdF5h3b',
#  655: '4AlW57XCAx',
#  656: 'bSSjXzzhIK',
#  657: '7kAwzsRDQh',
#  658: 'd2rARktiX4',
#  659: 'ALYNtcKDfR',
#  660: 'gdGaLUmino',
#  661: 'DvxnnMEDuB',
#  662: 'jDe1FEgi2X',
#  663: 'FVMEh77DAu',
#  664: 'mo3R9zZiHH',
#  665: 'I6kebr1DPe',
#  666: 'pOSs3jTiX1',
#  667: 'Lg95VbvEeO',
#  668: 'ryqIxUMjml',
#  669: 'OHYVPMoEu8',
#  670: 'uZFjrEGj1U',
#  671: 'QrwwJ6iE9r',
#  672: 'x9e9lyAjHE',
#  673: 'TRLMDqbEOb',
#  674: '0k2Zfj3jWy',
#  675: 'W2kn7bVEeL',
#  676: '2KR0ZTxkli',
#  677: 'Zc8D1LOFt4',
#  678: '5uqQTDqk1R',
#  679: 'cDXev6IF8o',
#  680: '8VErNykkGB',
#  681: 'enw4pqCFOY',
#  682: 'B5dHHidkVv',
#  683: 'hNKVja5FdI',
#  684: 'Ef2iBSXkle',
#  685: 'kyjvdLzFs1',
#  686: 'GGQ85DQl0O',
#  687: 'nY8LX5sG8l',
#  688: 'JqpZzxKlF8',
#  689: 'p8WmRpmGNV',
#  690: 'MREzthElVs',
#  691: 'sjvCLafGcF',
#  692: 'P1cQnS7lkb',
#  693: 'vJKdFKZGsy',
#  694: 'Rb1qhC1lzL',
#  695: 'yuj394SG7i',
#  696: 'UCQHbxumF5',
#  697: '1U7U3pMHMS',
#  698: 'XmphVhomUp',
#  699: '34WuxZGHcB',
#  700: 'aND8PRhmjY',
#  701: '6fvLrJ9Hrv',
#  702: 'dxcYJCbmzI',
#  703: '9FJll43H6f',
#  704: 'fX1yDwUmE2',
#  705: 'CqiCfowIMP',
#  706: 'i8PP7gOnTl',
#  707: 'FQ7cZZqIb8',
#  708: 'liop1RInjV',
#  709: 'H0V3TJjIqs',
#  710: 'oIDGvBBnyF',
#  711: 'KbuTN3dI6c',
#  712: 'qtbgpv5nDz',
#  713: 'NBJuHoWILL',
#  714: 'tT07jgynTi',
#  715: 'QlhKBYQJa5',
#  716: 'w4PXdQsoiS',
#  717: 'SM6k5IKJqp',
#  718: 'zenyXBloxC',
#  719: 'VwVBz3DJ5Z',
#  720: '2ECORvfoDw',
#  721: 'YXtbtn7JKI',
#  722: '4pbpLfYoSf',
#  723: 'b7I2nX0Ja2',
#  724: '7PzFFQSpiP',
#  725: 'ehhShIuKpm',
#  726: 'A0Og9AMpx9',
#  727: 'gI5tb2nK5W',
#  728: 'Dan63uFpCs',
#  729: 'jsUJVnhKKF',
#  730: 'FABXxf9pSc',
#  731: 'mStkPXaKZz',
#  732: 'IlaxrP2phM',
#  733: 'p3HAIHUKpj',
#  734: 'LLzNk9wqw6',
#  735: 'rdgbC2OL4S',
#  736: 'OvNoeupqCp',
#  737: 'uE516mHLJC',
#  738: 'RWmEYejqRZ',
#  739: 'xoTS0WBLZw',
#  740: 'T6BfSPdqgJ',
#  741: '0OssuH4Log',
#  742: 'WhZ5M9Wqw2',
#  743: '3zHJo1yM3P',
#  744: 'ZHyWGtQrBm',
#  745: '5ZfjilrMJ9',
#  746: 'crNwAeJrQW',
#  747: '8A4AcWlMYt',
#  748: 'fSlN4ODrgG',
#  749: 'BkTaWGfMnd',
#  750: 'h2Any86rvz',
#  751: 'EKr0Q1YM3M',
#  752: 'kdZEst0rAj',
#  753: 'GvGRKlSNI6',
#  754: 'nDxemdtsQT',
#  755: 'JVfrEVLNXq',
#  756: 'qnM5gNnsfD',
#  757: 'M53I8GFNnZ',
#  758: 'sOlVa8hsuw',
#  759: 'PgSi208N2J',
#  760: 'vy9wUsasAg',
#  761: 'SGr9wk2NH3',
#  762: 'yYYMOdUsPQ',
#  763: 'UrFZqVvOXn',
#  764: '19xmINNte9',
#  765: 'XRe0kFpOmW',
#  766: '4jLDC7Htut',
#  767: 'a13QezjO1G',
#  768: '6Kkd6sAt9d',
#  769: 'dcRrYkcOH0',
#  770: '9u940c4tON',
#  771: 'gCqHSUWOWk',
#  772: 'CUXUuMxue6',
#  773: 'inFiMFPPlT',
#  774: 'F5wvo7rutq',
#  775: 'lNd8GzJP1D',
#  776: 'HfLLirlu8a',
#  777: 'ox2ZAjCPGx',
#  778: 'KGkmcbeuOK',
#  779: 'rYRz4U6PVg',
#  780: 'Nq8CWMYud3',
#  781: 't8qPyEzPlQ',
#  782: 'QQXdQ6Rvsn',
#  783: 'wiEqsytQ0A',
#  784: 'T1w3KrLv8X',
#  785: 'zJdGmjnQFu',
#  786: 'VbKUEbEvNG',
#  787: '2t2hgTgQVd',
#  788: 'YBju8L8vc0',
#  789: '5UQ7aDaQkN',
#  790: 'bm8L261vsk',
#  791: '74pYUyTRz7',
#  792: 'eMWlwqvw7U',
#  793: 'AeEyOiNRFq',
#  794: 'gxvBqapwMD',
#  795: 'DFcPITGRUa',
#  796: 'jXKckLiwcx',
#  797: 'Gp1pCDARjK',
#  798: 'm7i2e5cwrh',
#  799: 'IQQG6x4Rz4',
#  800: 'pi7TYpVw6R',
#  801: 'L0og0ixSEn',
#  802: 'sIWtSaPxMA',
#  803: 'OaD7uSrSTX',
#  804: 'utuKMKIxbu',
#  805: 'RBcXoCkSjH',
#  806: 'xTJkG5Cxqe',
#  807: 'Ul0yixeSy1',
#  808: '03iBAp6x6N',
#  809: 'WLPOchXSDk',
#  810: '3e6b4ZzyL7',
#  811: 'ZwooWRRTTU',
#  812: '6EV2yKtybr',
#  813: 'cWCFQCKTiE',
#  814: '8ouSs4myqb',
#  815: 'f7bfKwETyx',
#  816: 'BPItmogy5K',
#  817: 'hh06Eh8TDh',
#  818: 'EzhJgZZyL4',
#  819: 'kHOW8R1TSR',
#  820: 'Ha6kaJTzao',
#  821: 'nsnx2BvUiB',
#  822: 'JAUAU3MzpY',
#  823: 'qSCNwwoUxu',
#  824: 'MktaOoGz5H',
#  825: 't3aoqgiUCe',
#  826: 'PLI1IYAzK1',
#  827: 'vdzEkQbUSO',
#  828: 'SvgRCJ3zZl',
#  829: 'yDOfeBVUh8',
#  830: 'VV5s63x0pU',
#  831: '1om5YvOVwr',
#  832: 'X6UI0nq04E',
#  833: '4OBWSfIVCb',
#  834: 'agsjuYk0Jy',
#  835: '6yawMQCVRL',
#  836: 'dHH9oId0Zi',
#  837: '9ZyNGA5Vg4',
#  838: 'grgai2X0oR',
#  839: 'C9NnAvzWwo',
#  840: 'iR40cnQ13B',
#  841: 'FkmD4fsWBY',
#  842: 'l2TRWXK1Jv',
#  843: 'IKAeyPmWQI',
#  844: 'ocsrQHE1Ye',
#  845: 'KuZ4sAfWg1',
#  846: 'rDGIK271nO',
#  847: 'NVyVmuZWvl',
#  848: 'unfiEm1138',
#  849: 'Q5MvgeSXAV',
#  850: 'wN498Xu2Is',
#  851: 'TglMaPMXQF',
#  852: 'zySZ2Ho2Xb',
#  853: 'WGAmU9GXfy',
#  854: '2Yrzw1h2nL',
#  855: 'YqYDOt9Xui',
#  856: '58GQqmb225',
#  857: 'bRxdIe3XAS',
#  858: '7jeqkWU3Hp',
#  859: 'e1M4COwYPB',
#  860: 'AJ3HdGO3XY',
#  861: 'hbkU59qYev',
#  862: 'DuShX1I3mI',
#  863: 'jC9vztjYuf',
#  864: 'GUr8RlB312',
#  865: 'mmYLtddY9P',
#  866: 'J4FYLV53Hl',
#  867: 'pNxmnOXYO8',
#  868: 'LfezFGy4WV',
#  869: 'sxLCh8QZes',
#  870: 'OF3P90s4lF',
#  871: 'vXkcbsKZtc',
#  872: 'RqRq3ll41z',
#  873: 'x893VdDZ8L',
#  874: 'UQqGxVf4Gi',
#  875: '0iXTPN7ZO5',
#  876: 'W0FhrFZ4VS',
#  877: '3JwuJ70adp',
#  878: 'Zbd7l0S5lC',
#  879: '6tLKDsuasZ',
#  880: 'cB2YfkM50w',
#  881: '8Tjl7cna8I',
#  882: 'flRyZUF5Ff',
#  883: 'B48B1NhaN2',
#  884: 'iMpOTF95VP',
#  885: 'EeXcv7bacm',
#  886: 'kwEpNz25k9',
#  887: 'HEv2prUbsW',
#  888: 'nXdFHjw6zs',
#  889: 'KpKTjcOb7F',
#  890: 'q71gBUp6Fc',
#  891: 'MPjtdMHbMz',
#  892: 'thQ65Ej6UM',
#  893: 'P07KX6Bbcj',
#  894: 'wIpXzzd6j6',
#  895: 'SaWkRr4brS',
#  896: 'ysDxtjW6zp',
#  897: 'VAvBLbyc6C',
#  898: '1TcOnTQ7EZ',
#  899: 'XlJbFLrcMw',
#  900: '431ohEJ7TJ',
#  901: 'aLi196lcbg',
#  902: '7dPFbyD7j3',
#  903: 'dw7S3qfcrP',
#  904: '9EofVi67ym',
#  905: 'gWVsxbYc69',
#  906: 'CoD6PT08EW',
#  907: 'j6uJrLSdLt',
#  908: 'FObWJDt8TG',
#  909: 'lhJjl5Ldbd',
#  910: 'Iz0xDxn8iz',
#  911: 'oHhAfqFdqM',
#  912: 'LZPN7ih8yj',
#  913: 'rr6aZa8d56',
#  914: 'NAnn1Sa8DT',
#  915: 'uSV1TK2dLq',
#  916: 'QkCEvDU9SD',
#  917: 'w2tRN5veaZ',
#  918: 'TKbepxN9iw',
#  919: 'zdIsHppepJ',
#  920: 'Wvz5jhH9xg',
#  921: '2DhIBZje53',
#  922: 'YVOVdSA9CQ',
#  923: '5n5j5KceKn',
#  924: 'b6nwXC49S9',
#  925: '8OU9z4WfZW',
#  926: 'egBMRwyAht',
#  927: 'AytatpPfpG',
#  928: 'hGanLhrAwd',
#  929: 'DYH0nZJf40',
#  930: 'krzDFRlACN',
#  931: 'G9gQhJCfJk',
#  932: 'mRNe9BeAR6',
#  933: 'Jj5rb46fZT',
#  934: 'p1m43wYAgq',
#  935: 'MKTHVo0goD',
#  936: 'scBVxgRBwa',
#  937: 'OusiPYtg3x',
#  938: 'vCZvrRLBBK',
#  939: 'RUH8JJngJg',
#  940: 'xnyMlBEBQ3',
#  941: 'U5fZD3ggYQ',
#  942: '0NNmfv8Bgn',
#  943: 'Xf4z7nagnA',
#  944: '3xlCZg2BvX',
#  945: 'ZGTQ1YTh3u',
#  946: '6YAdTQvCAG',
#  947: 'cqrqvINhId',
#  948: '98Z3NApCQ0',
#  949: 'fQGHp3GhXN',
#  950: 'BjyUHviCfk',
#  951: 'i1fhjnAhn7',
#  952: 'EJMuBfcCuU',
#  953: 'lb48dX4h2q',
#  954: 'HtlL5PVDAD',
#  955: 'nBSYXIxiHa',
#  956: 'KUAlzAPDPx',
#  957: 'qmrzR2riXK',
#  958: 'N4YCtuIDeh',
#  959: 'tMGPLmkim4',
#  960: 'PexcnfCDuR',
#  961: 'wxepFXei1n',
#  962: 'SFM3hP6D9A',
#  963: 'yX3G9HXiHX',
#  964: 'VpkTb9zEOu',
#  965: '17Sg31RjWH',
#  966: 'YQ9uVutEee',
#  967: '4iq7xmKjl1',
#  968: 'a0YKPemEtN',
#  969: '7IFXrWEj1k',
#  970: 'dawlJOgE87',
#  971: 'AteylH8jGU',
#  972: 'gBLBD9ZEOr',
#  973: 'CT2Of11kVE',
#  974: 'jlkb7tTFdb',
#  975: 'F3RpZlvklx',
#  976: 'mM821dMFsK',
#  977: 'IeqFTWok0h',
#  978: 'owXSvOGF84',
#  979: 'LEEgNGikFR',
#  980: 'rWwtp8AFNo',
#  981: 'Nod6H0bkVB',
#  982: 'u7KJjt3FcY',
#  983: 'QP2XBlVlku',
#  984: 'xhjkddxGsH',
#  985: 'TzQx5VOlze',
#  986: 'zH8AXNqG71',
#  987: 'WapOyFIlFO',
#  988: '2sWbQ8kGMl',
#  989: 'ZAEos0ClU8',
#  990: '5Sv1KsdGcU',
#  991: 'bkcEmk5lkr',
#  992: '83KSEcXHrE',
#  993: 'eL1fgVzmzb',
#  994: 'Bdis8NRH7y',
#  995: 'hvQ5aFsmEL',
#  996: 'DD7J27KHMi',
#  997: 'kWoWUzmmU4',
#  998: 'GoWjwrEHbR',
#  999: 'n6DwOkfmjo',
#  ...}

# %%
ndcg10 = validate(model, matrices, factors, iterations, regularization, show_progress=False)
print(ndcg10)
